# %%
bronze_train = spark.table("final_project.bronze.train")

# %%
bronze_row_count = bronze_train.count()
print(f"Rows in final_project.bronze.train: {bronze_row_count}")

# %%
assert bronze_row_count > 0, (
    "Data quality check failed: final_project.bronze.train is empty "
    "(row_count == 0)."
)

print("Data quality check passed: bronze train table is not empty.")
